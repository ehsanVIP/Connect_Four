# %%
def findingTop(board,col):
    if col<(board.shape[1]):
        lc = board.shape[0] -1
        if board[(lc)][col] == "O" : return lc 
        else :
            while board[lc][col] != "O":
                lc = lc-1
                if lc < 0 : 
                    break
            return lc
    else:
        lc = -1
        return lc

# %%
def printerOutput(board):
    rows = board.shape[0]
    cols = board.shape[1]
    for i in range(rows):
        for j in range(cols):
            print(board[i,j]," | ", end=' ')
        print("\n")
    print("----------------------------------------")
    for i in range(board.shape[1]):
        print(i,"   ",end =" ")

# %%
def checkInput(board,col,turn):
    cursor = findingTop(board,col)
    if cursor != -1:
        board[(cursor)][col] = turn
        return True
    else: 
        print('Input Error!')
        return False

# %%
import numpy as np

board = np.array([["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"]])
printerOutput(board)


turn = input("\nWho wants to Start the Game ? 1/2 : ")
if turn == "1" : turn_1 = True
else : turn_1 = False

while(True):
    
    if turn_1 == True:
        col = int(input("\nPlayer1 : Select a Column : "))
        if checkInput(board,col,"1"):
#         checkWinner(board)
#         printerOutput(board)
            turn_1 = False
    else:
        col = int(input("\nPlayer2 : Select a Column : "))
        if checkInput(board,col,"2"):
#         checkWinner(board)
#         printerOutput(board)
            turn_1 = True 
    printerOutput(board)
# Out:
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# ----------------------------------------
# 0     1     2     3     4     5     6
# Who wants to Start the Game ? 1/2 : 1
#
# Player1 : Select a Column : 1
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  1  |  O  |  O  |  O  |  O  |  O  |
#
# ----------------------------------------
# 0     1     2     3     4     5     6
# Player2 : Select a Column : 1
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# O  |  O  |  O  |  O  |  O  |  O  |  O  |
#
# ...
