# %%
def findingTop(board,col):
    if col<(board.shape[1]):
        lc = board.shape[0] -1
        if board[(lc)][col] == "O" : return lc 
        else :
            while board[lc][col] != "O":
                lc = lc-1
                if lc < 0 : 
                    break
            return lc
    else:
        return -1

# %%
def printerOutput(board):
    rows = board.shape[0]
    cols = board.shape[1]
    for i in range(rows):
        for j in range(cols):
            if j == 0 : print("| ", end=' ')
            print(board[i,j]," | ", end=' ')
        print(" ")
#         print("\n")
    print("-------------------------------------------")
    print("  ",end=' ')
    for i in range(board.shape[1]):
        print(i,"   ",end =" ")

# %%
def checkInput(board,col):
    cursor = findingTop(board,col)
    if cursor != -1:
        return True
    else: 
        return False

# %%
import numpy as np

board = np.array([["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"]])
printerOutput(board)


turn = input("\nWho wants to Start the Game ? 1/2 : ")
if turn == "1" : turn_1 = True
else : turn_1 = False

while(True):
    
    if turn_1 == True:
        col = int(input("\nPlayer 1 : Select a Column : "))
        if checkInput(board,col):
            cursor = findingTop(board,col)
            board[(cursor)][col] = "1"
            turn_1 = False
            
#             if checkWinner(board) : break
        else: 
            print('\nInput Error!')
            
    else:
        col = int(input("\nPlayer 2 : Select a Column : "))
        if checkInput(board,col):
            cursor = findingTop(board,col)
            board[(cursor)][col] = "2"
            turn_1 = True
            
#             if checkWinner(board) : break
        else: 
            print('\nInput Error!')
    printerOutput(board)
# Out:
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Who wants to Start the Game ? 1/2 : 1
#
# Player 1 : Select a Column : 2
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  1  |  O  |  O  |  O  |  O  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 2 : Select a Column : 5
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  1  |  O  |  O  |  2  |  O  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 1 : Select a Column : 6
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  1  |  O  |  O  |  2  |  1  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 2 : Select a Column : 7
#
# Input Error!
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  1  |  O  |  O  |  2  |  1  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 2 : Select a Column : 6
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  1  |  O  |  O  |  2  |  1  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 1 : Select a Column : 6
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  1  |  O  |  O  |  2  |  1  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 2 : Select a Column : 6
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  1  |  O  |  O  |  2  |  1  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 1 : Select a Column : 6
# |  O  |  O  |  O  |  O  |  O  |  O  |  O  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  1  |  O  |  O  |  2  |  1  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 2 : Select a Column : 6
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  1  |  O  |  O  |  2  |  1  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 1 : Select a Column : 6
#
# Input Error!
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  1  |  O  |  O  |  2  |  1  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 1 : Select a Column : 6
#
# Input Error!
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  1  |  O  |  O  |  2  |  1  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 1 : Select a Column : 6
#
# Input Error!
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  1  |  O  |  O  |  2  |  1  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 1 : Select a Column : 66
#
# Input Error!
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  1  |
# |  O  |  O  |  O  |  O  |  O  |  O  |  2  |
# |  O  |  O  |  1  |  O  |  O  |  2  |  1  |
# -------------------------------------------
#    0     1     2     3     4     5     6
