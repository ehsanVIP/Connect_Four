# %%
def findingTop(board,col):
    if col<(board.shape[1]):
        lc = board.shape[0] -1
        if board[(lc)][col] == "O" : return lc 
        else :
            while board[lc][col] != "O":
                lc = lc-1
                if lc < 0 : 
                    break
            return lc
    else:
        return -1

# %%
def printerOutput(board,symbol_O,symbol_1,symbol_2):
    
    rows = board.shape[0]
    cols = board.shape[1]
    
    
    for i in range(rows):
        for j in range(cols):
            if board[i][j] == "O" : board[i][j] = symbol_O
            if board[i][j] == "1" : board[i][j] = symbol_1
            if board[i][j] == "2" : board[i][j] = symbol_2
    
    
    
    for i in range(rows):
        for j in range(cols):
            if j == 0 : print("| ", end=' ')
            print(board[i][j]," | ", end=' ')
        print(" ")
#         print("\n")
    print("-------------------------------------------")
    print("  ",end=' ')
    for i in range(cols):
        print(i,"   ",end =" ")
        
        
    for i in range(rows):
        for j in range(cols):
            if board[i][j] == symbol_O : board[i][j] = "O"
            if board[i][j] == symbol_1 : board[i][j] = "1"
            if board[i][j] == symbol_2 : board[i][j] = "2"

# %%
def checkInput(board,col):
    cursor = findingTop(board,col)
    if cursor != -1:
        return True
    else: 
        return False

# %%
def checkWinner(board,symbol_O,symbol_1,symbol_2):
    
    symbol_1 = "\u25CF"
    symbol_2 = "\u2717"
    
    rows = board.shape[0]
    cols = board.shape[1]

    board2 = board[::-1,:]
    rows2 = board2.shape[0]
    cols2 = board2.shape[1]

    row_list = []
    col_list = []
    diag1_list = []
    diag2_list = []


    for i in range(rows):
        rr=[]
        result = ""
        for j in range(cols):
            rr.append(board[i][j])
        for k in rr:
            result = result + str(k)
        row_list.append(result)



    for i in range(cols):
        cc=[]
        result = ""
        for j in range(rows):
            cc.append(board[j][i])
        for k in cc:
            result = result + str(k)
        col_list.append(result)



    for i in range(3-cols,cols-3):
        dd = []
        result = ""
        dd.append(np.diag(board, k = i))
        for j in dd:
            result = result + str(j)
        result = result.replace("'", '')
        result = result.replace(" ","")
        result = result.replace("[","")
        result = result.replace("]","")
        diag1_list.append(result)  



    for i in range(3-cols2,cols2-3):
        dd = []
        result = ""
        dd.append(np.diag(board2, k = i))
        for j in dd:
            result = result + str(j)
        result = result.replace("'", '')
        result = result.replace(" ","")
        result = result.replace("[","")
        result = result.replace("]","")
        diag2_list.append(result)

    term_1= "1111"
    winner1 = "\nPlayer 1",symbol_1," is Winner"

    for i in row_list:
        if term_1 in i :
            printerOutput(board,symbol_O,symbol_1,symbol_2)
            print(winner1)
            return True
    for i in col_list:
        if term_1 in i :
            printerOutput(board,symbol_O,symbol_1,symbol_2)
            print(winner1)
            return True
    for i in diag1_list:
        if term_1 in i :
            printerOutput(board,symbol_O,symbol_1,symbol_2)
            print(winner1)
            return True
    for i in diag2_list:
        if term_1 in i : 
            printerOutput(board,symbol_O,symbol_1,symbol_2)
            print(winner1)
            return True

    term_2= "2222"
    winner2 = "\nPlayer 2 ",symbol_2," is Winner"

    for i in row_list:
        if term_2 in i : 
            printerOutput(board,symbol_O,symbol_1,symbol_2)
            print(winner2)
            return True
    for i in col_list:
        if term_2 in i : 
            printerOutput(board,symbol_O,symbol_1,symbol_2)
            print(winner2)
            return True
    for i in diag1_list:
        if term_2 in i : 
            printerOutput(board,symbol_O,symbol_1,symbol_2)
            print(winner2)
            return True
    for i in diag2_list:
        if term_2 in i : 
            printerOutput(board,symbol_O,symbol_1,symbol_2)
            print(winner2)
            return True
    for i in board :
        if "O" not in i:
            printerOutput(board,symbol_O,symbol_1,symbol_2)
            print('\nDraw')
            return True

# %%
import numpy as np

board = np.array([["O","O","O","1","O","O","O"],
                  ["O","O","O","4","O","8","O"],
                  ["O","O","7","3","O","O","O"],
                  ["5","4","O","4","O","O","O"],
                  ["2","2","3","5","5","6","8"],
                  ["O","O","O","5","O","O","O"]])

rows = board.shape[0]
cols = board.shape[1]
    
    
    
for i in range(rows):
    for j in range(cols):
        if board[i][j] == "O" : board[i][j] = "\u25CB"
        if board[i][j] == "1" : board[i][j] = "\u25CF"
        if board[i][j] == "2" : board[i][j] = "X"
print(board)
            
            

# for i in board:
#         for j in i:
#             if board == "O": board[i][j] = "\u25CB"
# print(board)
# Out:
# [['○' '○' '○' '●' '○' '○' '○']
#  ['○' '○' '○' '4' '○' '8' '○']
#  ['○' '○' '7' '3' '○' '○' '○']
#  ['5' '4' '○' '4' '○' '○' '○']
#  ['X' 'X' '3' '5' '5' '6' '8']
#  ['○' '○' '○' '5' '○' '○' '○']]

# %%
import numpy as np

board = np.array([["O","O","O","1","O","O","O"],
                  ["O","O","O","4","O","8","O"],
                  ["O","O","7","3","O","O","O"],
                  ["5","4","O","4","O","O","O"],
                  ["2","2","3","5","5","6","8"],
                  ["O","O","O","5","O","O","O"]])

rows = board.shape[0]
cols = board.shape[1]

board2 = board[::-1,:]
rows2 = board2.shape[0]
cols2 = board2.shape[1]

row_list = []
col_list = []
diag1_list = []
diag2_list = []

                
for i in range(rows):
    rr=[]
    result = ""
    for j in range(cols):
        rr.append(board[i][j])
    for k in rr:
        result = result + str(k)
    row_list.append(result)


                
for i in range(cols):
    cc=[]
    result = ""
    for j in range(rows):
        cc.append(board[j][i])
    for k in cc:
        result = result + str(k)
    col_list.append(result)
    
    
                
for i in range(3-cols,cols-3):
    dd = []
    result = ""
    dd.append(np.diag(board, k = i))
    for j in dd:
        result = result + str(j)
    result = result.replace("'", '')
    result = result.replace(" ","")
    result = result.replace("[","")
    result = result.replace("]","")
    diag1_list.append(result)  

    

for i in range(3-cols2,cols2-3):
    dd = []
    result = ""
    dd.append(np.diag(board2, k = i))
    for j in dd:
        result = result + str(j)
    result = result.replace("'", '')
    result = result.replace(" ","")
    result = result.replace("[","")
    result = result.replace("]","")
    diag2_list.append(result)
    
term_1= "1111"
winner1 = "\nPlayer 1 is Winner"

for i in row_list:
    if term_1 in i : 
        print(winner1)
        break
for i in col_list:
    if term_1 in i : 
        print(winner1)
        break
for i in diag1_list:
    if term_1 in i : 
        print(winner1)
        break
for i in diag2_list:
    if term_1 in i : 
        print(winner1)
        break

term_2= "2222"
winner2 = "\nPlayer 2 is Winner"

for i in row_list:
    if term_2 in i : 
        print(winner2)
        break
for i in col_list:
    if term_2 in i : 
        print(winner2)
        break
for i in diag1_list:
    if term_2 in i : 
        print(winner2)
        break
for i in diag2_list:
    if term_2 in i : 
        print(winner2)
        break


# print(np.diag(board , k = 6))
# board2 = board[::-1,:]


# >>> np.diag(x)
# array([0, 4, 8])
# >>> np.diag(x, k=1)
# array([1, 5])
# >>> np.diag(x, k=-1)
# array([3, 7])

# %%
list1=[1,2,3,4,5,6,7]
result=""
for i in list1:
    result = result + str(i)
print(result)
# Out:
# 1234567

# %%
import numpy as np

# board = np.array([["1","2","1","4","O","O","O"],
#                   ["2","3","4","5","O","4","4"],
#                   ["3","2","9","6","8","3","3"],
#                   ["1","5","7","8","9","1","3"],
#                   ["5","8","7","9","6","5","5"],
#                   ["9","7","7","8","5","2","4"]])
board = np.array([["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"],
                  ["O","O","O","O","O","O","O"]])

symbol_O = "\u25CB"
symbol_1 = "\u25CF"
symbol_2 = "\u2717"

printerOutput(board,symbol_O,symbol_1,symbol_2)


turn = input("\nWho wants to Start the Game ? 1/2 : ")
if turn == "1" : turn_1 = True
else : turn_1 = False

while(True):
    
    if turn_1 == True:
        col = int(input("\nPlayer 1 " "\u25CF" " : Select a Column : "))
        if checkInput(board,col):
            cursor = findingTop(board,col)
            board[(cursor)][col] = "1"
            turn_1 = False
            
            if checkWinner(board,symbol_O,symbol_1,symbol_2) : break
        else: 
            print('\nInput Error!')
            
    else:
        col = int(input("\nPlayer 2 " "\u2717" " : Select a Column : "))
        if checkInput(board,col):
            cursor = findingTop(board,col)
            board[(cursor)][col] = "2"
            turn_1 = True
            
            if checkWinner(board,symbol_O,symbol_1,symbol_2) : break
        else: 
            print('\nInput Error!')
    printerOutput(board,symbol_O,symbol_1,symbol_2)
# Out:
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Who wants to Start the Game ? 1/2 : 1
#
# Player 1 ● : Select a Column : 0
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# |  ●  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# -------------------------------------------
#    0     1     2     3     4     5     6
# Player 2 ✗ : Select a Column : 0
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |  ○  |
# ...

# %%
print("\u25CF")
print("\u25CB")
text = "Ehsan"
a = "\u25CB"
print(a)
a =1
print(a)
# print('\033[1;32m'+text+'\033[1;m')
# # dayere ghermez:
# print("\033[1;31;40m\u25CF \n")
# print("\033[1;34;40m\u25CF \n")
# Out:
# ●
# ○
# ○
# 1
